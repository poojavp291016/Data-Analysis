# %%
import os
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from textstat import flesch_reading_ease, flesch_kincaid_grade

# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('cmudict')

# Load stop words
stop_words = set(stopwords.words('english'))

# Function to clean text
def clean_text(text):
    tokens = word_tokenize(text)
    cleaned_tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]
    return cleaned_tokens

# Function to count syllables in a word
def syllable_count(word):
    d = nltk.corpus.cmudict.dict()
    if word.lower() in d:
        return max([len(list(y for y in x if y[-1].isdigit())) for x in d[word.lower()]])
    else:
        # Simple fallback for words not found in CMU Pronouncing Dictionary
        return max(1, len(word) // 3)

# Function to calculate sentiment scores
def calculate_sentiment_scores(tokens, positive_words, negative_words):
    positive_score = sum(1 for word in tokens if word in positive_words)
    negative_score = sum(1 for word in tokens if word in negative_words)
    polarity_score = (positive_score - negative_score) / (positive_score + negative_score + 0.000001)
    subjectivity_score = (positive_score + negative_score) / (len(tokens) + 0.000001)
    return positive_score, negative_score, polarity_score, subjectivity_score

# Load positive and negative words
positive_words_file = "C:\\Users\\pooja\\Downloads\\positive-words.txt"
negative_words_file = "C:\\Users\\pooja\\Downloads\\negative-words.txt"

positive_words = set()
negative_words = set()

# Read positive words from file
with open(positive_words_file, 'r') as file:
    for line in file:
        word = line.strip()
        positive_words.add(word)

# Read negative words from file
with open(negative_words_file, 'r') as file:
    for line in file:
        word = line.strip()
        negative_words.add(word)

# Replace "extracted_articles" with the path to your directory containing extracted articles
directory_path = "C:\\Users\\pooja\\Downloads\\extracted_articles"

# Process each text file
for filename in os.listdir(directory_path):
    with open(os.path.join(directory_path, filename), 'r', encoding='utf-8') as file:
        text = file.read()
        cleaned_tokens = clean_text(text)
        positive_score, negative_score, polarity_score, subjectivity_score = calculate_sentiment_scores(cleaned_tokens, positive_words, negative_words)
        
        # Additional features
        sentences = sent_tokenize(text)
        word_count = len(cleaned_tokens)
        avg_sentence_length = word_count / len(sentences)
        complex_word_count = sum(1 for word in cleaned_tokens if len(word) > 2)  # Considering words with more than 2 characters as complex
        percentage_complex_words = (complex_word_count / word_count) * 100
        
        # Calculate FOG Index
        fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)
        
        print(f"File: {filename}")
        print(f"Average Sentence Length: {avg_sentence_length}")
        print(f"FOG Index: {fog_index}")
        print(f"Word Count: {word_count}")
        print("------------------")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pooja\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pooja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package cmudict to
# [nltk_data]     C:\Users\pooja\AppData\Roaming\nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
# File: blackassign0001.txt
# Average Sentence Length: 10.833333333333334
# FOG Index: 43.96410256410257
# Word Count: 325
# ------------------
# File: blackassign0002.txt
# Average Sentence Length: 11.78048780487805
# FOG Index: 44.46374791698228
# Word Count: 966
# ------------------
# File: blackassign0003.txt
# Average Sentence Length: 12.918032786885245
# FOG Index: 45.01492885079472
# Word Count: 788
# ------------------
# File: blackassign0004.txt
# Average Sentence Length: 14.178571428571429
# FOG Index: 45.419539402662835
# Word Count: 794
# ------------------
# File: blackassign0005.txt
# Average Sentence Length: 12.25
# FOG Index: 44.751576994434146
# Word Count: 539
# ------------------
# File: blackassign0006.txt
# Average Sentence Length: 13.46236559139785
# FOG Index: 44.96961077330036
# Word Count: 1252
# ------------------
# File: blackassign0007.txt
# Average Sentence Length: 10.619047619047619
# FOG Index: 43.82908392056375
# Word Count: 669
# ------------------
# File: blackassign0008.txt
# Average Sentence Length: 11.76923076923077
# FOG Index: 43.92337858220211
# Word Count: 612
# ------------------
# File: blackassign0009.txt
# Average Sentence Length: 19.363636363636363
# FOG Index: 46.99428083653436
# Word Count: 213
# ------------------
# File: blackassign0084.txt
# Average Sentence Length: 13.568181818181818
# FOG Index: 45.2262677021471
# Word Count: 597
# ------------------
# File: blackassign0085.txt
# Average Sentence Length: 8.296
# FOG Index: 43.20268158148506
# Word Count: 1037
# ------------------
# File: blackassign0086.txt
# Average Sentence Length: 10.90625
# FOG Index: 44.17147803247374
# Word Count: 1047
# ------------------
# File: blackassign0087.txt
# Average Sentence Length: 14.411764705882353
# FOG Index: 45.38375350140056
# Word Count: 735
# ------------------
# File: blackassign0088.txt
# Average Sentence Length: 16.338461538461537
# FOG Index: 46.00807764739969
# Word Count: 1062
# ------------------
# File: blackassign0089.txt
# Average Sentence Length: 12.557692307692308
# FOG Index: 44.839309694899285
# Word Count: 653
# ------------------
# File: blackassign0090.txt
# Average Sentence Length: 9.820512820512821
# FOG Index: 43.614889201312174
# Word Count: 766
# ------------------
# File: blackassign0091.txt
# Average Sentence Length: 17.30952380952381
# FOG Index: 46.37360319643676
# Word Count: 727
# ------------------
# File: blackassign0092.txt
# Average Sentence Length: 13.783333333333333
# FOG Index: 45.27149536477228
# Word Count: 827
# ------------------
# File: blackassign0093.txt
# Average Sentence Length: 16.714285714285715
# FOG Index: 45.83101343101344
# Word Count: 234
# ------------------
# File: blackassign0094.txt
# Average Sentence Length: 11.161764705882353
# FOG Index: 44.1485003487561
# Word Count: 759
# ------------------
# File: blackassign0095.txt
# Average Sentence Length: 12.05
# FOG Index: 44.48804979253112
# Word Count: 482
# ------------------
# File: blackassign0096.txt
# Average Sentence Length: 14.092592592592593
# FOG Index: 45.37422494768093
# Word Count: 761
# ------------------
# File: blackassign0097.txt
# Average Sentence Length: 15.186046511627907
# FOG Index: 45.89065137647353
# Word Count: 653
# ------------------
# File: blackassign0098.txt
# Average Sentence Length: 27.0
# FOG Index: 50.47078189300412
# Word Count: 243
# ------------------
# File: blackassign0099.txt
# Average Sentence Length: 13.151515151515152
# FOG Index: 44.984108364753524
# Word Count: 434
# ------------------
# File: blackassign0100.txt
# Average Sentence Length: 17.742857142857144
# FOG Index: 46.9683183804923
# Word Count: 621
# ------------------

# %%
import os
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

# Download NLTK resources (if not already downloaded)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('cmudict')

# Load stop words
stop_words = set(stopwords.words('english'))

# Function to clean text
def clean_text(text):
    tokens = word_tokenize(text)
    cleaned_tokens = [word.lower() for word in tokens if word.isalpha() and word.lower() not in stop_words]
    return cleaned_tokens

# Function to count syllables in a word
def syllable_count(word):
    d = nltk.corpus.cmudict.dict()
    if word.lower() in d:
        return max([len(list(y for y in x if y[-1].isdigit())) for x in d[word.lower()]])
    else:
        # Simple fallback for words not found in CMU Pronouncing Dictionary
        return max(1, len(word) // 3)

# Replace "extracted_articles" with the path to your directory containing extracted articles
directory_path = "C:\\Users\\pooja\\Downloads\\extracted_articles"

# Process each text file
for filename in os.listdir(directory_path):
    with open(os.path.join(directory_path, filename), 'r', encoding='utf-8') as file:
        text = file.read()
        cleaned_tokens = clean_text(text)
        
        # Additional features
        sentences = sent_tokenize(text)
        word_count = len(cleaned_tokens)
        avg_sentence_length = word_count / len(sentences)
        complex_word_count = sum(1 for word in cleaned_tokens if len(word) > 2)  # Considering words with more than 2 characters as complex
        percentage_complex_words = (complex_word_count / word_count) * 100
        
        print(f"File: {filename}")
        print(f"Percentage of Complex Words: {percentage_complex_words}")
        print(f"Avg Number of Words per Sentence: {avg_sentence_length}")
        print(f"Complex Word Count: {complex_word_count}")
        print("------------------")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pooja\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\pooja\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package cmudict to
# [nltk_data]     C:\Users\pooja\AppData\Roaming\nltk_data...
# [nltk_data]   Package cmudict is already up-to-date!
# File: blackassign0001.txt
# Percentage of Complex Words: 99.07692307692308
# Avg Number of Words per Sentence: 10.833333333333334
# Complex Word Count: 322
# ------------------
# File: blackassign0002.txt
# Percentage of Complex Words: 99.37888198757764
# Avg Number of Words per Sentence: 11.78048780487805
# Complex Word Count: 960
# ------------------
# File: blackassign0003.txt
# Percentage of Complex Words: 99.61928934010153
# Avg Number of Words per Sentence: 12.918032786885245
# Complex Word Count: 785
# ------------------
# File: blackassign0004.txt
# Percentage of Complex Words: 99.37027707808565
# Avg Number of Words per Sentence: 14.178571428571429
# Complex Word Count: 789
# ------------------
# File: blackassign0005.txt
# Percentage of Complex Words: 99.62894248608535
# Avg Number of Words per Sentence: 12.25
# Complex Word Count: 537
# ------------------
# File: blackassign0006.txt
# Percentage of Complex Words: 98.96166134185303
# Avg Number of Words per Sentence: 13.46236559139785
# Complex Word Count: 1239
# ------------------
# File: blackassign0007.txt
# Percentage of Complex Words: 98.95366218236174
# Avg Number of Words per Sentence: 10.619047619047619
# Complex Word Count: 662
# ------------------
# File: blackassign0008.txt
# Percentage of Complex Words: 98.0392156862745
# Avg Number of Words per Sentence: 11.76923076923077
# Complex Word Count: 600
# ------------------
# File: blackassign0009.txt
# Percentage of Complex Words: 99.734395750332
# Avg Number of Words per Sentence: 12.14516129032258
# Complex Word Count: 751
# ------------------
# File: blackassign0010.txt
# Percentage of Complex Words: 99.78189749182116
# Avg Number of Words per Sentence: 10.788235294117648
# Complex Word Count: 915
# ------------------
# File: blackassign0011.txt
# Percentage of Complex Words: 99.26701570680628
# Avg Number of Words per Sentence: 13.26388888888889
# Complex Word Count: 948
# ------------------
# File: blackassign0012.txt
# Percentage of Complex Words: 99.82238010657194
# Avg Number of Words per Sentence: 13.404761904761905
# Complex Word Count: 1124
# ------------------
# File: blackassign0013.txt
# Percentage of Complex Words: 99.56236323851203
# Avg Number of Words per Sentence: 15.758620689655173
# Complex Word Count: 455
# ------------------
# File: blackassign0014.txt
# Percentage of Complex Words: 99.3103448275862
# Avg Number of Words per Sentence: 9.931506849315069
# Complex Word Count: 720
# ------------------
# File: blackassign0015.txt
# Percentage of Complex Words: 99.76580796252928
# Avg Number of Words per Sentence: 13.34375
# Complex Word Count: 852
# ------------------
# File: blackassign0016.txt
# Percentage of Complex Words: 99.76580796252928
# Avg Number of Words per Sentence: 13.34375
# Complex Word Count: 852
# ------------------
# File: blackassign0017.txt
# Percentage of Complex Words: 98.33333333333333
# Avg Number of Words per Sentence: 11.64179104477612
# Complex Word Count: 767
# ------------------
# File: blackassign0018.txt
# Percentage of Complex Words: 99.44674965421854
# Avg Number of Words per Sentence: 14.755102040816327
# Complex Word Count: 719
# ------------------
# File: blackassign0019.txt
# Percentage of Complex Words: 99.7164461247637
# Avg Number of Words per Sentence: 10.58
# Complex Word Count: 1055
# ------------------
# File: blackassign0020.txt
# Percentage of Complex Words: 99.49748743718592
# Avg Number of Words per Sentence: 13.266666666666667
# Complex Word Count: 396
# ------------------
# File: blackassign0021.txt
# Percentage of Complex Words: 99.19137466307278
# Avg Number of Words per Sentence: 13.74074074074074
# Complex Word Count: 736
# ------------------
# File: blackassign0022.txt
# Percentage of Complex Words: 99.42528735632183
# Avg Number of Words per Sentence: 10.875
# Complex Word Count: 346
# ------------------
# File: blackassign0023.txt
# Percentage of Complex Words: 99.42987457240594
# Avg Number of Words per Sentence: 12.897058823529411
# Complex Word Count: 872
# ------------------
# File: blackassign0024.txt
# Percentage of Complex Words: 98.4478935698448
# Avg Number of Words per Sentence: 18.04
# Complex Word Count: 444
# ------------------
# File: blackassign0025.txt
# Percentage of Complex Words: 97.91976225854383
# Avg Number of Words per Sentence: 22.433333333333334
# Complex Word Count: 659
# ------------------
# File: blackassign0026.txt
# Percentage of Complex Words: 98.45201238390094
# Avg Number of Words per Sentence: 14.043478260869565
# Complex Word Count: 636
# ------------------
# File: blackassign0027.txt
# Percentage of Complex Words: 99.11949685534591
# Avg Number of Words per Sentence: 13.706896551724139
# Complex Word Count: 788
# ------------------
# File: blackassign0028.txt
# Percentage of Complex Words: 99.30555555555556
# Avg Number of Words per Sentence: 16.363636363636363
# Complex Word Count: 715
# ------------------
# File: blackassign0029.txt
# Percentage of Complex Words: 96.94533762057877
# Avg Number of Words per Sentence: 15.55
# Complex Word Count: 1206
# ------------------
# File: blackassign0030.txt
# Percentage of Complex Words: 96.78530424799081
# Avg Number of Words per Sentence: 10.24705882352941
# Complex Word Count: 843
# ------------------
# File: blackassign0031.txt
# Percentage of Complex Words: 98.39715048975958
# Avg Number of Words per Sentence: 12.477777777777778
# Complex Word Count: 1105
# ------------------
# File: blackassign0032.txt
# Percentage of Complex Words: 95.87939698492463
# Avg Number of Words per Sentence: 10.257731958762887
# Complex Word Count: 954
# ------------------
# File: blackassign0033.txt
# Percentage of Complex Words: 98.8527724665392
# Avg Number of Words per Sentence: 12.75609756097561
# Complex Word Count: 1034
# ------------------
# File: blackassign0034.txt
# Percentage of Complex Words: 98.34605597964376
# Avg Number of Words per Sentence: 12.885245901639344
# Complex Word Count: 773
# ------------------
# File: blackassign0035.txt
# Percentage of Complex Words: 98.69158878504672
# Avg Number of Words per Sentence: 10.7
# Complex Word Count: 528
# ------------------
# File: blackassign0036.txt
# Percentage of Complex Words: 98.66666666666667
# Avg Number of Words per Sentence: 25.0
# Complex Word Count: 148
# ------------------
# File: blackassign0037.txt
# Percentage of Complex Words: 99.2248062015504
# Avg Number of Words per Sentence: 12.585365853658537
# Complex Word Count: 512
# ------------------
# File: blackassign0038.txt
# Percentage of Complex Words: 96.18380062305296
# Avg Number of Words per Sentence: 14.930232558139535
# Complex Word Count: 1235
# ------------------
# File: blackassign0039.txt
# Percentage of Complex Words: 99.66072943172179
# Avg Number of Words per Sentence: 12.410526315789474
# Complex Word Count: 1175
# ------------------
# File: blackassign0040.txt
# Percentage of Complex Words: 99.01840490797545
# Avg Number of Words per Sentence: 12.936507936507937
# Complex Word Count: 807
# ------------------
# File: blackassign0041.txt
# Percentage of Complex Words: 95.87264150943396
# Avg Number of Words per Sentence: 9.86046511627907
# Complex Word Count: 813
# ------------------
# File: blackassign0042.txt
# Percentage of Complex Words: 96.79144385026738
# Avg Number of Words per Sentence: 14.166666666666666
# Complex Word Count: 905
# ------------------
# File: blackassign0043.txt
# Percentage of Complex Words: 95.94320486815415
# Avg Number of Words per Sentence: 11.6
# Complex Word Count: 946
# ------------------
# File: blackassign0044.txt
# Percentage of Complex Words: 97.48283752860412
# Avg Number of Words per Sentence: 16.185185185185187
# Complex Word Count: 426
# ------------------
# File: blackassign0045.txt
# Percentage of Complex Words: 96.72447013487476
# Avg Number of Words per Sentence: 74.14285714285714
# Complex Word Count: 1004
# ------------------
# File: blackassign0046.txt
# Percentage of Complex Words: 99.46140035906643
# Avg Number of Words per Sentence: 11.14
# Complex Word Count: 554
# ------------------
# File: blackassign0047.txt
# Percentage of Complex Words: 99.08256880733946
# Avg Number of Words per Sentence: 12.11111111111111
# Complex Word Count: 540
# ------------------
# File: blackassign0048.txt
# Percentage of Complex Words: 99.19028340080972
# Avg Number of Words per Sentence: 20.583333333333332
# Complex Word Count: 245
# ------------------
# File: blackassign0049.txt
# Percentage of Complex Words: 98.66666666666667
# Avg Number of Words per Sentence: 25.0
# Complex Word Count: 148
# ------------------
# File: blackassign0050.txt
# Percentage of Complex Words: 99.77220956719817
# Avg Number of Words per Sentence: 14.633333333333333
# Complex Word Count: 876
# ------------------
# File: blackassign0051.txt
# Percentage of Complex Words: 97.15370018975332
# Avg Number of Words per Sentence: 15.5
# Complex Word Count: 512
# ------------------
# File: blackassign0052.txt
# Percentage of Complex Words: 97.33944954128441
# Avg Number of Words per Sentence: 9.56140350877193
# Complex Word Count: 1061
# ------------------
# File: blackassign0053.txt
# Percentage of Complex Words: 99.0138067061144
# Avg Number of Words per Sentence: 10.5625
# Complex Word Count: 502
# ------------------
# File: blackassign0054.txt
# Percentage of Complex Words: 99.4475138121547
# Avg Number of Words per Sentence: 17.238095238095237
# Complex Word Count: 360
# ------------------
# File: blackassign0055.txt
# Percentage of Complex Words: 99.31506849315068
# Avg Number of Words per Sentence: 14.974358974358974
# Complex Word Count: 580
# ------------------
# File: blackassign0056.txt
# Percentage of Complex Words: 95.88377723970945
# Avg Number of Words per Sentence: 17.208333333333332
# Complex Word Count: 396
# ------------------
# File: blackassign0057.txt
# Percentage of Complex Words: 99.3975903614458
# Avg Number of Words per Sentence: 10.375
# Complex Word Count: 330
# ------------------
# File: blackassign0058.txt
# Percentage of Complex Words: 99.14893617021276
# Avg Number of Words per Sentence: 15.666666666666666
# Complex Word Count: 233
# ------------------
# File: blackassign0059.txt
# Percentage of Complex Words: 98.69646182495345
# Avg Number of Words per Sentence: 8.95
# Complex Word Count: 530
# ------------------
# File: blackassign0060.txt
# Percentage of Complex Words: 98.7603305785124
# Avg Number of Words per Sentence: 17.285714285714285
# Complex Word Count: 239
# ------------------
# File: blackassign0061.txt
# Percentage of Complex Words: 99.24528301886792
# Avg Number of Words per Sentence: 14.722222222222221
# Complex Word Count: 526
# ------------------
# File: blackassign0062.txt
# Percentage of Complex Words: 98.61111111111111
# Avg Number of Words per Sentence: 21.6
# Complex Word Count: 213
# ------------------
# File: blackassign0063.txt
# Percentage of Complex Words: 98.75776397515527
# Avg Number of Words per Sentence: 11.925925925925926
# Complex Word Count: 318
# ------------------
# File: blackassign0064.txt
# Percentage of Complex Words: 99.0
# Avg Number of Words per Sentence: 13.924050632911392
# Complex Word Count: 1089
# ------------------
# File: blackassign0065.txt
# Percentage of Complex Words: 99.50347567030785
# Avg Number of Words per Sentence: 13.608108108108109
# Complex Word Count: 1002
# ------------------
# File: blackassign0066.txt
# Percentage of Complex Words: 98.46153846153847
# Avg Number of Words per Sentence: 10.459770114942529
# Complex Word Count: 896
# ------------------
# File: blackassign0067.txt
# Percentage of Complex Words: 99.60552268244575
# Avg Number of Words per Sentence: 7.567164179104478
# Complex Word Count: 505
# ------------------
# File: blackassign0068.txt
# Percentage of Complex Words: 99.37106918238993
# Avg Number of Words per Sentence: 11.357142857142858
# Complex Word Count: 790
# ------------------
# File: blackassign0069.txt
# Percentage of Complex Words: 98.92761394101876
# Avg Number of Words per Sentence: 18.65
# Complex Word Count: 369
# ------------------
# File: blackassign0070.txt
# Percentage of Complex Words: 95.52529182879378
# Avg Number of Words per Sentence: 13.891891891891891
# Complex Word Count: 982
# ------------------
# File: blackassign0071.txt
# Percentage of Complex Words: 99.35897435897436
# Avg Number of Words per Sentence: 7.703703703703703
# Complex Word Count: 620
# ------------------
# File: blackassign0072.txt
# Percentage of Complex Words: 98.90859481582538
# Avg Number of Words per Sentence: 8.623529411764705
# Complex Word Count: 725
# ------------------
# File: blackassign0073.txt
# Percentage of Complex Words: 99.15254237288136
# Avg Number of Words per Sentence: 14.75
# Complex Word Count: 702
# ------------------
# File: blackassign0074.txt
# Percentage of Complex Words: 99.59568733153638
# Avg Number of Words per Sentence: 11.415384615384616
# Complex Word Count: 739
# ------------------
# File: blackassign0075.txt
# Percentage of Complex Words: 99.21507064364206
# Avg Number of Words per Sentence: 8.166666666666666
# Complex Word Count: 632
# ------------------
# File: blackassign0076.txt
# Percentage of Complex Words: 99.59183673469387
# Avg Number of Words per Sentence: 14.411764705882353
# Complex Word Count: 488
# ------------------
# File: blackassign0077.txt
# Percentage of Complex Words: 99.32885906040269
# Avg Number of Words per Sentence: 19.866666666666667
# Complex Word Count: 296
# ------------------
# File: blackassign0078.txt
# Percentage of Complex Words: 99.64349376114082
# Avg Number of Words per Sentence: 19.344827586206897
# Complex Word Count: 559
# ------------------
# File: blackassign0079.txt
# Percentage of Complex Words: 99.11949685534591
# Avg Number of Words per Sentence: 13.032786885245901
# Complex Word Count: 788
# ------------------
# File: blackassign0080.txt
# Percentage of Complex Words: 99.46601941747572
# Avg Number of Words per Sentence: 10.3
# Complex Word Count: 2049
# ------------------
# File: blackassign0081.txt
# Percentage of Complex Words: 99.03660886319847
# Avg Number of Words per Sentence: 11.795454545454545
# Complex Word Count: 1028
# ------------------
# File: blackassign0082.txt
# Percentage of Complex Words: 99.40944881889764
# Avg Number of Words per Sentence: 15.875
# Complex Word Count: 1010
# ------------------
# File: blackassign0083.txt
# Percentage of Complex Words: 98.12206572769952
# Avg Number of Words per Sentence: 19.363636363636363
# Complex Word Count: 209
# ------------------
# File: blackassign0084.txt
# Percentage of Complex Words: 99.49748743718592
# Avg Number of Words per Sentence: 13.568181818181818
# Complex Word Count: 594
# ------------------
# File: blackassign0085.txt
# Percentage of Complex Words: 99.71070395371264
# Avg Number of Words per Sentence: 8.296
# Complex Word Count: 1034
# ------------------
# File: blackassign0086.txt
# Percentage of Complex Words: 99.52244508118434
# Avg Number of Words per Sentence: 10.90625
# Complex Word Count: 1042
# ------------------
# File: blackassign0087.txt
# Percentage of Complex Words: 99.04761904761905
# Avg Number of Words per Sentence: 14.411764705882353
# Complex Word Count: 728
# ------------------
# File: blackassign0088.txt
# Percentage of Complex Words: 98.68173258003766
# Avg Number of Words per Sentence: 16.338461538461537
# Complex Word Count: 1048
# ------------------
# File: blackassign0089.txt
# Percentage of Complex Words: 99.5405819295559
# Avg Number of Words per Sentence: 12.557692307692308
# Complex Word Count: 650
# ------------------
# File: blackassign0090.txt
# Percentage of Complex Words: 99.21671018276761
# Avg Number of Words per Sentence: 9.820512820512821
# Complex Word Count: 760
# ------------------
# File: blackassign0091.txt
# Percentage of Complex Words: 98.62448418156808
# Avg Number of Words per Sentence: 17.30952380952381
# Complex Word Count: 717
# ------------------
# File: blackassign0092.txt
# Percentage of Complex Words: 99.39540507859735
# Avg Number of Words per Sentence: 13.783333333333333
# Complex Word Count: 822
# ------------------
# File: blackassign0093.txt
# Percentage of Complex Words: 97.86324786324786
# Avg Number of Words per Sentence: 16.714285714285715
# Complex Word Count: 229
# ------------------
# File: blackassign0094.txt
# Percentage of Complex Words: 99.2094861660079
# Avg Number of Words per Sentence: 11.161764705882353
# Complex Word Count: 753
# ------------------
# File: blackassign0095.txt
# Percentage of Complex Words: 99.1701244813278
# Avg Number of Words per Sentence: 12.05
# Complex Word Count: 478
# ------------------
# File: blackassign0096.txt
# Percentage of Complex Words: 99.34296977660972
# Avg Number of Words per Sentence: 14.092592592592593
# Complex Word Count: 756
# ------------------
# File: blackassign0097.txt
# Percentage of Complex Words: 99.5405819295559
# Avg Number of Words per Sentence: 15.186046511627907
# Complex Word Count: 650
# ------------------
# File: blackassign0098.txt
# Percentage of Complex Words: 99.1769547325103
# Avg Number of Words per Sentence: 27.0
# Complex Word Count: 241
# ------------------
# File: blackassign0099.txt
# Percentage of Complex Words: 99.30875576036865
# Avg Number of Words per Sentence: 13.151515151515152
# Complex Word Count: 431
# ------------------
# File: blackassign0100.txt
# Percentage of Complex Words: 99.6779388083736
# Avg Number of Words per Sentence: 17.742857142857144
# Complex Word Count: 619
# ------------------
